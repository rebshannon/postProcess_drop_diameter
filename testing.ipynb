# %%
import os
import re
import pandas as pd
from scipy.spatial import cKDTree
import numpy as np
import time
from scipy import ndimage
import csv
import fluidfoam

# %%
os.chdir('/projectnb/aeracous/REBECCA/DOD_CAVSYM/U267_D2_B2')

# %%
timeList = pd.read_csv('timeList.csv',header=None,dtype=str).to_numpy()

# %%
print(timeList[1][0])
# Out:
# 2e-06

# %%
pres_test = fluidfoam.readof.readfield('.',timeList2[2][0],'p_rgh')
# Out:
# Reading file ./3e-06/p_rgh.gz

# %%
mesh = fluidfoam.readof.readmesh('.')
# Out:
# Reading file ./constant/polyMesh/owner.gz
# Reading file ./constant/polyMesh/faces.gz
# Reading file ./constant/polyMesh/points.gz
# Reading file ./constant/polyMesh/neighbour.gz
